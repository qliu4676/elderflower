# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
# %run -i Run_Fitting.py
# Out:
# mu: 460.20 , ZP: 27.10 , pix_scale: 2.50
# Threosholds: [27.5 23.5] [  82213.49875987 3272978.33725943]
# # of medium bright (flux:8.3e+04~2.5e+06) stars: 62
# # of very bright (flux>1.6e+07) stars : 3
# Crowded fields w/ bright stars > 50, will draw in parallel.
#
# Generate base image of faint stars (flux < 8.2e+04).
# Total Time: 2.382 s
#
# Detect and deblend source... Mask S/N > 3.0 (5th enlarged)
# Use mask map built from catalog
# Mask core regions: r < 36 (36) pix
# Use sky strips crossing very bright stars
# Only model brightest stars in the field.
# Estimate of Background: (462.347, 3.030)
#
# Opening new pool: # of CPU used: 3
# Run Nested Fitting for the image... Dim of params: 7
# iter: 1920 | batch: 2 | bound: 146 | nc: 10 | ncall: 12698 | eff(%): 15.120 | loglstar: -474887.245 < -474881.965 < -474884.482 | logz: -474914.169 +/-  1.067 | stop:  7.068
# Finish Fitting! Total time elapsed: 2.6e+03 s
#
# Pool Closed.
# ...
