# %%
from utils import *
from modeling import *
from plotting import *

# %load_ext autoreload
# %autoreload 2
# "[1000, 1400, 1800, 2200], [1800, 2400, 2800, 3400], [3100, 1400, 4100, 2400]"

# %%
# %run Measure_Rnorm_SE.py -f "g" -r 10 -m 15 -b "[1000, 1400, 1800, 2200], [1800, 2400, 2800, 3400], [3100, 1400, 4100, 2400]"
# Out:
# Measure the intensity at R = 10 for stars < 15.0 as normalization of fitting
#
# BKG: 460.20 , std: 4.17 , ZP: 27.10 , pix_scale: 2.50
#
# Match field [700, 700, 5050, 3550] with catalog
#
# Measure Sky Patch (X min, Y min, X max, Y max) :
# [1000, 1400, 1800, 2200]
# [1800, 2400, 2800, 3400]
# [3100, 1400, 4100, 2400]
# /home/qliu/Desktop/PSF/Measure_Rnorm_SE.py:90: RuntimeWarning: invalid value encountered in log10
#   mag = -2.5 * np.log10(flux) + ZP
# Search 1.806 deg around:
# <SkyCoord (FK5: equinox=2000.0): (ra, dec) in deg
#     (228.97437372, 56.32951389)>
# Pan-STARRS rmag:  6.675 ~ 22.998
# Pan-STARRS gmag:  7.754 ~ 28.284
# Matched stars with Pan-STARRS rmag:  6.675 ~ 22.156
# Matched bright stars with Pan-STARRS rmag:  6.675 ~ 14.999
#
# Average Color Term [SE-catalog] = -0.12938
# Fit 3th empirical relation of (X1) aperture radii for catalog stars based on SE.
# Make segmentation map based on catalog PS gmag: 3696 stars
# ...
